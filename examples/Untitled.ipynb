# %%
# Make sure modules are reimported each time to update changes
# %reload_ext autoreload
# %autoreload 2

import BoreFlow

# %%
# help(BoreFlow)

# help(BoreFlow.load_and_pass_data)

pc_csv = "./example_data/climate_data/palaeoclimate_data/palaeoclimate_surface_temperatures.csv"

test = BoreFlow.BoreClass(pc_csv)

# %%
print(dir(test))

print(test.palaeoclimate)
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'palaeoclimate']
#     T1 (ka)  T2 (ka)    dT  sigma_dT
# 0       0.0      3.5   0.0       0.5
# 1       3.5      7.5   2.0       0.5
# 2       7.5     11.5   0.0       0.5
# 3      11.5     12.8  -8.0       0.5
# 4      12.8     14.7  -4.0       0.5
# 5      14.7     16.5 -19.5       0.5
# 6      16.5     30.0 -10.0       0.5
# 7      30.0     45.0 -14.0       0.5
# 8      45.0     65.0 -10.0       0.5
# 9      65.0     75.0 -18.0       0.5
# 10     75.0    120.0  -6.0       0.5
# 11    120.0    130.0   5.0       0.5
# 12    130.0   3000.0  -4.0       0.5
# 13   3000.0  65000.0   5.0       0.5
